# %% [markdown]
# # MK Praktikum Unggulan Universitas Gunadarma
# # Mata Kuliah: Praktikum Terapan Teori Graf (Tingkat 3)

# %% [markdown]
# ---
# # Pertemuan VI

# %%
graph = {
    'A' : ['B','C'],
    'B' : ['D', 'E'],
    'C' : [],
    'D' : [],
    'E' : ['F'],
    'F' : []
}
# Menambahkan kode program dari materi DFS Flow
graph_val = {"A": 10, 'B': 12, 'C': 3, 'D': 4, 'E': -6, 'F': -5}

# %%
visited = set() # Set to keep track of visited nodes.

# %%
leaf = set() # Menambahkan kode program dari materi DFS Flow

# %%
def dfs(visited, graph, node):
    if node not in visited:
        visited.add(node)
        # Menambahkan kode program dari materi DFS Flow
        if len(graph[node]) == 0:
            leaf.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

# %%
def leaf_sum(leaf):
    jmlh = 0
    for leaf_node in leaf:
        leaf_val = graph_val[leaf_node]
        jmlh = jmlh + leaf_val
        
    return jmlh

# %%
dfs(visited, graph, 'A')

# %%
leaf_sum(leaf)

# %% [markdown]
# ---
#
#
# Copyright © Pengelola MK Praktikum Unggulan (Praktikum DGX), Universitas Gunadarma
#
#
# https://www.praktikum-hpc.gunadarma.ac.id/
